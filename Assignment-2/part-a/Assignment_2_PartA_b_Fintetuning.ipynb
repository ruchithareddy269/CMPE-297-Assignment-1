# %% [markdown]
# # Assignment-2 Part-A-b

# %%
# !pip install transformers datasets trl
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Collecting datasets
#   Downloading datasets-3.0.0-py3-none-any.whl.metadata (19 kB)
# Collecting trl
#   Downloading trl-0.10.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.5)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from trl) (2.4.0+cu121)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from trl) (0.34.2)
# Collecting tyro>=0.5.11 (from trl)
#   Downloading tyro-0.8.10-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.1.4)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (13.8.1)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->trl) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4.0->trl) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Downloading datasets-3.0.0-py3-none-any.whl (474 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.3/474.3 kB 17.5 MB/s eta 0:00:00
# Downloading trl-0.10.1-py3-none-any.whl (280 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.1/280.1 kB 26.7 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.5 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 20.1 MB/s eta 0:00:00
# Downloading tyro-0.8.10-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 10.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.8 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.0 MB/s eta 0:00:00
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Installing collected packages: xxhash, shtab, pyarrow, dill, multiprocess, tyro, datasets, trl
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed datasets-3.0.0 dill-0.3.8 multiprocess-0.70.16 pyarrow-17.0.0 shtab-1.7.1 trl-0.10.1 tyro-0.8.10 xxhash-3.5.0

# %%
# %cd /content/
# %rm -rf LLaMA-Factory
# !git clone https://github.com/hiyouga/LLaMA-Factory.git
# %cd LLaMA-Factory
# %ls
# !pip install -e .[torch,bitsandbytes]
# Out:
# /content
# Cloning into 'LLaMA-Factory'...
# remote: Enumerating objects: 17255, done.
# remote: Counting objects: 100% (7802/7802), done.
# remote: Compressing objects: 100% (556/556), done.
# remote: Total 17255 (delta 7415), reused 7246 (delta 7246), pack-reused 9453 (from 1)
# Receiving objects: 100% (17255/17255), 226.11 MiB | 13.84 MiB/s, done.
# Resolving deltas: 100% (12708/12708), done.
# /content/LLaMA-Factory
# assets/       docker/      LICENSE      pyproject.toml  requirements.txt  src/
# CITATION.cff  evaluation/  Makefile     README.md       scripts/          tests/
# data/         examples/    MANIFEST.in  README_zh.md    setup.py
# Obtaining file:///content/LLaMA-Factory
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: transformers<=4.45.0,>=4.41.2 in /usr/local/lib/python3.10/dist-packages (from llamafactory==0.9.1.dev0) (4.44.2)
# Collecting datasets<=2.21.0,>=2.16.0 (from llamafactory==0.9.1.dev0)
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: accelerate<=0.34.2,>=0.30.1 in /usr/local/lib/python3.10/dist-packages (from llamafactory==0.9.1.dev0) (0.34.2)
# Collecting peft<=0.12.0,>=0.11.1 (from llamafactory==0.9.1.dev0)
#   Downloading peft-0.12.0-py3-none-any.whl.metadata (13 kB)
# Collecting trl<=0.9.6,>=0.8.6 (from llamafactory==0.9.1.dev0)
#   Downloading trl-0.9.6-py3-none-any.whl.metadata (12 kB)
# Collecting gradio>=4.0.0 (from llamafactory==0.9.1.dev0)
#   Downloading gradio-4.44.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from llamafactory==0.9.1.dev0) (2.1.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from llamafactory==0.9.1.dev0) (1.13.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from llamafactory==0.9.1.dev0) (0.8.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from llamafactory==0.9.1.dev0) (0.1.99)
# Collecting tiktoken (from llamafactory==0.9.1.dev0)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from llamafactory==0.9.1.dev0) (3.20.3)
# Collecting uvicorn (from llamafactory==0.9.1.dev0)
#   Downloading uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from llamafactory==0.9.1.dev0) (2.9.1)
# Collecting fastapi (from llamafactory==0.9.1.dev0)
#   Downloading fastapi-0.114.2-py3-none-any.whl.metadata (27 kB)
# Collecting sse-starlette (from llamafactory==0.9.1.dev0)
#   Downloading sse_starlette-2.1.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from llamafactory==0.9.1.dev0) (3.7.1)
# Collecting fire (from llamafactory==0.9.1.dev0)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from llamafactory==0.9.1.dev0) (24.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from llamafactory==0.9.1.dev0) (6.0.2)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from llamafactory==0.9.1.dev0) (1.26.4)
# Collecting bitsandbytes>=0.39.0 (from llamafactory==0.9.1.dev0)
#   Downloading bitsandbytes-0.43.3-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: torch>=1.13.1 in /usr/local/lib/python3.10/dist-packages (from llamafactory==0.9.1.dev0) (2.4.0+cu121)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate<=0.34.2,>=0.30.1->llamafactory==0.9.1.dev0) (5.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate<=0.34.2,>=0.30.1->llamafactory==0.9.1.dev0) (0.24.6)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate<=0.34.2,>=0.30.1->llamafactory==0.9.1.dev0) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (3.16.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (4.66.5)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (3.10.5)
# Collecting aiofiles<24.0,>=22.0 (from gradio>=4.0.0->llamafactory==0.9.1.dev0)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.0.0->llamafactory==0.9.1.dev0) (3.7.1)
# Collecting ffmpy (from gradio>=4.0.0->llamafactory==0.9.1.dev0)
#   Downloading ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.3.0 (from gradio>=4.0.0->llamafactory==0.9.1.dev0)
#   Downloading gradio_client-1.3.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting httpx>=0.24.1 (from gradio>=4.0.0->llamafactory==0.9.1.dev0)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.0.0->llamafactory==0.9.1.dev0) (6.4.5)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.0.0->llamafactory==0.9.1.dev0) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.0.0->llamafactory==0.9.1.dev0) (2.1.5)
# Collecting orjson~=3.0 (from gradio>=4.0.0->llamafactory==0.9.1.dev0)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.0.0->llamafactory==0.9.1.dev0) (9.4.0)
# Collecting pydub (from gradio>=4.0.0->llamafactory==0.9.1.dev0)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio>=4.0.0->llamafactory==0.9.1.dev0)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Collecting ruff>=0.2.2 (from gradio>=4.0.0->llamafactory==0.9.1.dev0)
#   Downloading ruff-0.6.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting semantic-version~=2.0 (from gradio>=4.0.0->llamafactory==0.9.1.dev0)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio>=4.0.0->llamafactory==0.9.1.dev0)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.0.0->llamafactory==0.9.1.dev0) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.0.0->llamafactory==0.9.1.dev0) (4.12.2)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.0.0->llamafactory==0.9.1.dev0) (2.0.7)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.3.0->gradio>=4.0.0->llamafactory==0.9.1.dev0)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi->llamafactory==0.9.1.dev0)
#   Downloading starlette-0.38.5-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.1.dev0) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.1.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.1.dev0) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.1.dev0) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.1.dev0) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.1.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->llamafactory==0.9.1.dev0) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->llamafactory==0.9.1.dev0) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->llamafactory==0.9.1.dev0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /usr/local/lib/python3.10/dist-packages (from pydantic->llamafactory==0.9.1.dev0) (2.23.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.1->llamafactory==0.9.1.dev0) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.1->llamafactory==0.9.1.dev0) (3.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.45.0,>=4.41.2->llamafactory==0.9.1.dev0) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.45.0,>=4.41.2->llamafactory==0.9.1.dev0) (0.19.1)
# Requirement already satisfied: tyro>=0.5.11 in /usr/local/lib/python3.10/dist-packages (from trl<=0.9.6,>=0.8.6->llamafactory==0.9.1.dev0) (0.8.10)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn->llamafactory==0.9.1.dev0) (8.1.7)
# Collecting h11>=0.8 (from uvicorn->llamafactory==0.9.1.dev0)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire->llamafactory==0.9.1.dev0) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->llamafactory==0.9.1.dev0) (2.4.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio>=4.0.0->llamafactory==0.9.1.dev0) (3.8)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio>=4.0.0->llamafactory==0.9.1.dev0) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio>=4.0.0->llamafactory==0.9.1.dev0) (1.2.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (4.0.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio>=4.0.0->llamafactory==0.9.1.dev0) (2024.8.30)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio>=4.0.0->llamafactory==0.9.1.dev0)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets<=2.21.0,>=2.16.0->llamafactory==0.9.1.dev0) (3.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio>=4.0.0->llamafactory==0.9.1.dev0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio>=4.0.0->llamafactory==0.9.1.dev0) (13.8.1)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl<=0.9.6,>=0.8.6->llamafactory==0.9.1.dev0) (0.16)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl<=0.9.6,>=0.8.6->llamafactory==0.9.1.dev0) (1.7.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.1->llamafactory==0.9.1.dev0) (1.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio>=4.0.0->llamafactory==0.9.1.dev0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio>=4.0.0->llamafactory==0.9.1.dev0) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio>=4.0.0->llamafactory==0.9.1.dev0) (0.1.2)
# Downloading bitsandbytes-0.43.3-py3-none-manylinux_2_24_x86_64.whl (137.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 MB 7.0 MB/s eta 0:00:00
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 39.9 MB/s eta 0:00:00
# Downloading gradio-4.44.0-py3-none-any.whl (18.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 73.7 MB/s eta 0:00:00
# Downloading gradio_client-1.3.0-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 28.0 MB/s eta 0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading fastapi-0.114.2-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 9.8 MB/s eta 0:00:00
# Downloading peft-0.12.0-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 26.6 MB/s eta 0:00:00
# Downloading trl-0.9.6-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.8/245.8 kB 24.2 MB/s eta 0:00:00
# Downloading uvicorn-0.30.6-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 6.5 MB/s eta 0:00:00
# Downloading sse_starlette-2.1.3-py3-none-any.whl (9.4 kB)
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 66.7 MB/s eta 0:00:00
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.6 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 8.6 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.9 MB/s eta 0:00:00
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 14.3 MB/s eta 0:00:00
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading ruff-0.6.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 101.2 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.38.5-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 7.5 MB/s eta 0:00:00
# Downloading ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 15.2 MB/s eta 0:00:00
# Building wheels for collected packages: llamafactory, fire
#   Building editable for llamafactory (pyproject.toml) ... done
#   Created wheel for llamafactory: filename=llamafactory-0.9.1.dev0-0.editable-py3-none-any.whl size=22352 sha256=15816d04f91a98698478261df79e8b475265d71ee2bb7d40ab83377bcc13cf9a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qmpzxzoo/wheels/de/aa/c5/27b5682c5592b7c0eecc3e208f176dedf6b11a61cf2a910b85
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=e7894baaee6972a6fcc0184b621a08e7667c40385527c45660b03e71e6eca00b
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built llamafactory fire
# Installing collected packages: pydub, websockets, tomlkit, semantic-version, ruff, python-multipart, orjson, h11, fire, ffmpy, aiofiles, uvicorn, tiktoken, starlette, httpcore, sse-starlette, httpx, fastapi, bitsandbytes, gradio-client, peft, gradio, datasets, trl, llamafactory
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.13.2
#     Uninstalling tomlkit-0.13.2:
#       Successfully uninstalled tomlkit-0.13.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.0.0
#     Uninstalling datasets-3.0.0:
#       Successfully uninstalled datasets-3.0.0
#   Attempting uninstall: trl
#     Found existing installation: trl 0.10.1
#     Uninstalling trl-0.10.1:
#       Successfully uninstalled trl-0.10.1
# Successfully installed aiofiles-23.2.1 bitsandbytes-0.43.3 datasets-2.21.0 fastapi-0.114.2 ffmpy-0.4.0 fire-0.6.0 gradio-4.44.0 gradio-client-1.3.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 llamafactory-0.9.1.dev0 orjson-3.10.7 peft-0.12.0 pydub-0.25.1 python-multipart-0.0.9 ruff-0.6.5 semantic-version-2.10.0 sse-starlette-2.1.3 starlette-0.38.5 tiktoken-0.7.0 tomlkit-0.12.0 trl-0.9.6 uvicorn-0.30.6 websockets-12.0

# %%
from huggingface_hub import notebook_login

notebook_login()  # This will prompt you to enter your Hugging Face token
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Finetune Gemma - LORA

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# Example with a public model (GPT-NeoX)
model_name = "EleutherAI/gpt-neox-20b"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto")
# Out:
# tokenizer_config.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/457k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:12:29,694 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/vocab.json
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:12:29,698 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/merges.txt
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:12:29,700 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/tokenizer.json
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:12:29,706 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:12:29,710 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:12:29,717 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/tokenizer_config.json
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# [INFO|tokenization_utils_base.py:2513] 2024-09-16 06:12:30,040 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# [INFO|configuration_utils.py:733] 2024-09-16 06:12:30,878 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/config.json
# [INFO|configuration_utils.py:800] 2024-09-16 06:12:30,890 >> Model config GPTNeoXConfig {
#   "_name_or_path": "EleutherAI/gpt-neox-20b",
#   "architectures": [
#     "GPTNeoXForCausalLM"
#   ],
#   "attention_bias": true,
#   "attention_dropout": 0.0,
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 0,
#   "classifier_dropout": 0.1,
#   "eos_token_id": 0,
#   "hidden_act": "gelu_fast",
#   "hidden_dropout": 0.0,
#   "hidden_dropout_prob": 0,
#   "hidden_size": 6144,
#   "initializer_range": 0.02,
#   "intermediate_size": 24576,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 2048,
#   "model_type": "gpt_neox",
#   "num_attention_heads": 64,
#   "num_hidden_layers": 44,
#   "rope_scaling": null,
#   "rotary_emb_base": 10000,
#   "rotary_pct": 0.25,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "use_parallel_residual": true,
#   "vocab_size": 50432
# }
# model.safetensors.index.json:   0%|          | 0.00/60.4k [00:00<?, ?B/s]
# [INFO|modeling_utils.py:3678] 2024-09-16 06:12:31,832 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/model.safetensors.index.json
# Downloading shards:   0%|          | 0/46 [00:00<?, ?it/s]
# model-00001-of-00046.safetensors:   0%|          | 0.00/926M [00:00<?, ?B/s]
# model-00002-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00003-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00004-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00005-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00006-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00007-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00008-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00009-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00010-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00011-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00012-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00013-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00014-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00015-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00016-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00017-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00018-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00019-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00020-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00021-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00022-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00023-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00024-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00025-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00026-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00027-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00028-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00029-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00030-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00031-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00032-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00033-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00034-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00035-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00036-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00037-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00038-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00039-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00040-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00041-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00042-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00043-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00044-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00045-of-00046.safetensors:   0%|          | 0.00/604M [00:00<?, ?B/s]
# model-00046-of-00046.safetensors:   0%|          | 0.00/620M [00:00<?, ?B/s]
# [INFO|configuration_utils.py:1038] 2024-09-16 06:16:27,577 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "eos_token_id": 0
# }
# Loading checkpoint shards:   0%|          | 0/46 [00:00<?, ?it/s]
# [INFO|modeling_utils.py:4507] 2024-09-16 06:17:24,295 >> All model checkpoint weights were used when initializing GPTNeoXForCausalLM.
#
# [INFO|modeling_utils.py:4515] 2024-09-16 06:17:24,310 >> All the weights of GPTNeoXForCausalLM were initialized from the model checkpoint at EleutherAI/gpt-neox-20b.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use GPTNeoXForCausalLM for predictions without further training.
# [INFO|modeling_utils.py:4003] 2024-09-16 06:17:24,573 >> Generation config file not found, using a generation config created from the model config.
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the disk and cpu.

# %%
from huggingface_hub import HfApi

HF_TOKEN = "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"

tokenizer = AutoTokenizer.from_pretrained(model_name, use_auth_token=HF_TOKEN)
model = AutoModelForCausalLM.from_pretrained(model_name, use_auth_token=HF_TOKEN, device_map="auto")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:786: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:20:05,405 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/vocab.json
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:20:05,406 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/merges.txt
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:20:05,409 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/tokenizer.json
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:20:05,411 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:20:05,413 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:20:05,416 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2513] 2024-09-16 06:20:05,539 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:469: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# [INFO|configuration_utils.py:733] 2024-09-16 06:20:05,783 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/config.json
# [INFO|configuration_utils.py:800] 2024-09-16 06:20:05,785 >> Model config GPTNeoXConfig {
#   "_name_or_path": "EleutherAI/gpt-neox-20b",
#   "architectures": [
#     "GPTNeoXForCausalLM"
#   ],
#   "attention_bias": true,
#   "attention_dropout": 0.0,
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 0,
#   "classifier_dropout": 0.1,
#   "eos_token_id": 0,
#   "hidden_act": "gelu_fast",
#   "hidden_dropout": 0.0,
#   "hidden_dropout_prob": 0,
#   "hidden_size": 6144,
#   "initializer_range": 0.02,
#   "intermediate_size": 24576,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 2048,
#   "model_type": "gpt_neox",
#   "num_attention_heads": 64,
#   "num_hidden_layers": 44,
#   "rope_scaling": null,
#   "rotary_emb_base": 10000,
#   "rotary_pct": 0.25,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "use_parallel_residual": true,
#   "vocab_size": 50432
# }
#
# [INFO|modeling_utils.py:3678] 2024-09-16 06:20:05,789 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/model.safetensors.index.json
# [INFO|configuration_utils.py:1038] 2024-09-16 06:20:05,805 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "eos_token_id": 0
# }
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/modeling.py:1462: UserWarning: Current model requires 40372464.0 bytes of buffer for offloaded layers, which seems does not fit any GPU's remaining memory. If you are experiencing a OOM later, please consider using offload_buffers=True.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/46 [00:00<?, ?it/s]
# [INFO|modeling_utils.py:4507] 2024-09-16 06:20:11,910 >> All model checkpoint weights were used when initializing GPTNeoXForCausalLM.
#
# [INFO|modeling_utils.py:4515] 2024-09-16 06:20:11,912 >> All the weights of GPTNeoXForCausalLM were initialized from the model checkpoint at EleutherAI/gpt-neox-20b.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use GPTNeoXForCausalLM for predictions without further training.
# [INFO|modeling_utils.py:4003] 2024-09-16 06:20:12,172 >> Generation config file not found, using a generation config created from the model config.
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the disk.

# %% [markdown]
# ### Run Inference

# %%
# %cd /content/LLaMA-Factory/src/

from llamafactory.chat import ChatModel
from llamafactory.extras.misc import torch_gc

# %cd /content/LLaMA-Factory/

args = dict(
    model_name_or_path="EleutherAI/gpt-neox-20b",  # use Gemma 2B model
    adapter_name_or_path="gemma_lora",  # load the saved LoRA adapters
    template="gemma",  # same to the one in training
    finetuning_type="lora",  # same to the one in training
    quantization_bit=4,  # load 4-bit quantized model
)
chat_model = ChatModel(args)

messages = []
print(
    "Welcome to the CLI application, use `clear` to remove the history, use `exit` to exit the application."
)
while True:
    query = input("\nUser: ")
    if query.strip() == "exit":
        break
    if query.strip() == "clear":
        messages = []
        torch_gc()
        print("History has been removed.")
        continue

    messages.append({"role": "user", "content": query})
    print("Assistant: ", end="", flush=True)

    response = ""
    for new_text in chat_model.stream_chat(messages):
        print(new_text, end="", flush=True)
        response += new_text
    print()
    messages.append({"role": "assistant", "content": response})

torch_gc()
# Out:
# /content/LLaMA-Factory/src
# /content/LLaMA-Factory
# [INFO|configuration_utils.py:733] 2024-09-16 06:22:49,519 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/config.json
# [INFO|configuration_utils.py:800] 2024-09-16 06:22:49,526 >> Model config GPTNeoXConfig {
#   "_name_or_path": "EleutherAI/gpt-neox-20b",
#   "architectures": [
#     "GPTNeoXForCausalLM"
#   ],
#   "attention_bias": true,
#   "attention_dropout": 0.0,
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 0,
#   "classifier_dropout": 0.1,
#   "eos_token_id": 0,
#   "hidden_act": "gelu_fast",
#   "hidden_dropout": 0.0,
#   "hidden_dropout_prob": 0,
#   "hidden_size": 6144,
#   "initializer_range": 0.02,
#   "intermediate_size": 24576,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 2048,
#   "model_type": "gpt_neox",
#   "num_attention_heads": 64,
#   "num_hidden_layers": 44,
#   "rope_scaling": null,
#   "rotary_emb_base": 10000,
#   "rotary_pct": 0.25,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "use_parallel_residual": true,
#   "vocab_size": 50432
# }
#
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:22:49,763 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/vocab.json
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:22:49,769 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/merges.txt
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:22:49,773 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/tokenizer.json
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:22:49,777 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:22:49,784 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:22:49,787 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2513] 2024-09-16 06:22:49,999 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|configuration_utils.py:733] 2024-09-16 06:22:51,037 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/config.json
# [INFO|configuration_utils.py:800] 2024-09-16 06:22:51,043 >> Model config GPTNeoXConfig {
#   "_name_or_path": "EleutherAI/gpt-neox-20b",
#   "architectures": [
#     "GPTNeoXForCausalLM"
#   ],
#   "attention_bias": true,
#   "attention_dropout": 0.0,
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 0,
#   "classifier_dropout": 0.1,
#   "eos_token_id": 0,
#   "hidden_act": "gelu_fast",
#   "hidden_dropout": 0.0,
#   "hidden_dropout_prob": 0,
#   "hidden_size": 6144,
#   "initializer_range": 0.02,
#   "intermediate_size": 24576,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 2048,
#   "model_type": "gpt_neox",
#   "num_attention_heads": 64,
#   "num_hidden_layers": 44,
#   "rope_scaling": null,
#   "rotary_emb_base": 10000,
#   "rotary_pct": 0.25,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "use_parallel_residual": true,
#   "vocab_size": 50432
# }
#
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:22:51,284 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/vocab.json
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:22:51,290 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/merges.txt
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:22:51,295 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/tokenizer.json
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:22:51,297 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:22:51,301 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2269] 2024-09-16 06:22:51,303 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2513] 2024-09-16 06:22:51,494 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 09/16/2024 06:22:51 - INFO - llamafactory.data.template - Add pad token: <|endoftext|>
# [INFO|configuration_utils.py:733] 2024-09-16 06:22:51,768 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/config.json
# [INFO|configuration_utils.py:800] 2024-09-16 06:22:51,774 >> Model config GPTNeoXConfig {
#   "_name_or_path": "EleutherAI/gpt-neox-20b",
#   "architectures": [
#     "GPTNeoXForCausalLM"
#   ],
#   "attention_bias": true,
#   "attention_dropout": 0.0,
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 0,
#   "classifier_dropout": 0.1,
#   "eos_token_id": 0,
#   "hidden_act": "gelu_fast",
#   "hidden_dropout": 0.0,
#   "hidden_dropout_prob": 0,
#   "hidden_size": 6144,
#   "initializer_range": 0.02,
#   "intermediate_size": 24576,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 2048,
#   "model_type": "gpt_neox",
#   "num_attention_heads": 64,
#   "num_hidden_layers": 44,
#   "rope_scaling": null,
#   "rotary_emb_base": 10000,
#   "rotary_pct": 0.25,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "use_parallel_residual": true,
#   "vocab_size": 50432
# }
# 09/16/2024 06:22:51 - INFO - llamafactory.model.model_utils.quantization - Quantizing model to 4 bit with bitsandbytes.
# 09/16/2024 06:22:51 - INFO - llamafactory.model.patcher - Using KV cache for faster generation.
# [INFO|modeling_utils.py:3678] 2024-09-16 06:22:51,825 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--EleutherAI--gpt-neox-20b/snapshots/c292233c833e336628618a88a648727eb3dff0a7/model.safetensors.index.json
# [INFO|modeling_utils.py:1606] 2024-09-16 06:22:51,841 >> Instantiating GPTNeoXForCausalLM model under default dtype torch.float16.
# [INFO|configuration_utils.py:1038] 2024-09-16 06:22:51,848 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "eos_token_id": 0
# }
# Loading checkpoint shards:   0%|          | 0/46 [00:00<?, ?it/s]
# [INFO|modeling_utils.py:4507] 2024-09-16 06:26:03,384 >> All model checkpoint weights were used when initializing GPTNeoXForCausalLM.
#
# [INFO|modeling_utils.py:4515] 2024-09-16 06:26:03,390 >> All the weights of GPTNeoXForCausalLM were initialized from the model checkpoint at EleutherAI/gpt-neox-20b.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use GPTNeoXForCausalLM for predictions without further training.
# [INFO|modeling_utils.py:4003] 2024-09-16 06:26:03,639 >> Generation config file not found, using a generation config created from the model config.
# 09/16/2024 06:26:04 - INFO - llamafactory.model.model_utils.attention - Using torch SDPA for faster training and inference.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     303     try:
# --> 304         response.raise_for_status()
#     305     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/gemma_lora/resolve/main/adapter_config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/peft/config.py in _get_peft_type(cls, model_id, **hf_hub_download_kwargs)
#     204             try:
# --> 205                 config_file = hf_hub_download(
#     206                     model_id,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py in inner_f(*args, **kwargs)
#     100                 warnings.warn(message, FutureWarning)
# --> 101             return f(*args, **kwargs)
#     102
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, legacy_cache_layout, resume_download, force_filename, local_dir_use_symlinks)
#    1239     else:
# -> 1240         return _hf_hub_download_to_cache_dir(
#    1241             # Destination
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1346         # Otherwise, raise appropriate error
# -> 1347         _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1348
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1853         # Repo not found or gated => let's raise the actual error
# -> 1854         raise head_call_error
#    1855     else:
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1750             try:
# -> 1751                 metadata = get_hf_file_metadata(
#    1752                     url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers)
#    1672     # Retrieve metadata
# -> 1673     r = _request_wrapper(
#    1674         method="HEAD",
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     375     if follow_relative_redirects:
# --> 376         response = _request_wrapper(
#     377             method=method,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     399     response = get_session().request(method=method, url=url, **params)
# --> 400     hf_raise_for_status(response)
#     401     return response
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     351             )
# --> 352             raise RepositoryNotFoundError(message, response) from e
#     353
#
# RepositoryNotFoundError: 404 Client Error. (Request ID: Root=1-66e7cf7c-5be23dbf5a598f6a258ccfdb;790040e3-b094-492b-b839-290cfee75293)
#
# Repository Not Found for url: https://huggingface.co/gemma_lora/resolve/main/adapter_config.json.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b36b5171b7a6> in <cell line: 15>()
#      13     quantization_bit=4,  # load 4-bit quantized model
#      14 )
# ---> 15 chat_model = ChatModel(args)
#      16
#      17 messages = []
#
# /content/LLaMA-Factory/src/llamafactory/chat/chat_model.py in __init__(self, args)
#      50         self.engine_type = model_args.infer_backend
#      51         if model_args.infer_backend == "huggingface":
# ---> 52             self.engine: "BaseEngine" = HuggingfaceEngine(model_args, data_args, finetuning_args, generating_args)
#      53         elif model_args.infer_backend == "vllm":
#      54             self.engine: "BaseEngine" = VllmEngine(model_args, data_args, finetuning_args, generating_args)
#
# /content/LLaMA-Factory/src/llamafactory/chat/hf_engine.py in __init__(self, model_args, data_args, finetuning_args, generating_args)
#      57         self.tokenizer.padding_side = "left" if self.can_generate else "right"
#      58         self.template = get_template_and_fix_tokenizer(self.tokenizer, data_args)
# ---> 59         self.model = load_model(
#      60             self.tokenizer, model_args, finetuning_args, is_trainable=False, add_valuehead=(not self.can_generate)
#      61         )  # must after fixing tokenizer to resize vocab
#
# /content/LLaMA-Factory/src/llamafactory/model/loader.py in load_model(tokenizer, model_args, finetuning_args, is_trainable, add_valuehead)
#     169         register_autoclass(config, model, tokenizer)
#     170
# --> 171     model = init_adapter(config, model, model_args, finetuning_args, is_trainable)
#     172
#     173     if add_valuehead:
#
# /content/LLaMA-Factory/src/llamafactory/model/adapter.py in init_adapter(config, model, model_args, finetuning_args, is_trainable)
#     297         _setup_freeze_tuning(model, finetuning_args, is_trainable, cast_trainable_params_to_fp32)
#     298     elif finetuning_args.finetuning_type == "lora":
# --> 299         model = _setup_lora_tuning(
#     300             config, model, model_args, finetuning_args, is_trainable, cast_trainable_params_to_fp32
#     301         )
#
# /content/LLaMA-Factory/src/llamafactory/model/adapter.py in _setup_lora_tuning(config, model, model_args, finetuning_args, is_trainable, cast_trainable_params_to_fp32)
#     189                 model = load_unsloth_peft_model(config, model_args, is_trainable=is_trainable)
#     190             else:
# --> 191                 model = PeftModel.from_pretrained(model, adapter_to_resume, is_trainable=is_trainable, **init_kwargs)
#     192
#     193         logger.info("Loaded adapter(s): {}".format(",".join(model_args.adapter_name_or_path)))
#
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py in from_pretrained(cls, model, model_id, adapter_name, is_trainable, config, autocast_adapter_dtype, ephemeral_gpu_offload, **kwargs)
#     451         if config is None:
#     452             config = PEFT_TYPE_TO_CONFIG_MAPPING[
# --> 453                 PeftConfig._get_peft_type(
#     454                     model_id,
#     455                     subfolder=kwargs.get("subfolder", None),
#
# /usr/local/lib/python3.10/dist-packages/peft/config.py in _get_peft_type(cls, model_id, **hf_hub_download_kwargs)
#     209                 )
#     210             except Exception:
# --> 211                 raise ValueError(f"Can't find '{CONFIG_NAME}' at '{model_id}'")
#     212
#     213         loaded_attributes = cls.from_json_file(config_file)
#
# ValueError: Can't find 'adapter_config.json' at 'gemma_lora'
